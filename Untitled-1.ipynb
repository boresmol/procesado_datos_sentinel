# %%
# !pip install patchify
# !pip install split-folders
# Out:
# Requirement already satisfied: patchify in /home/algirosfs6/.local/lib/python3.10/site-packages (0.2.3)
# Requirement already satisfied: numpy<2,>=1 in /home/algirosfs6/.local/lib/python3.10/site-packages (from patchify) (1.23.5)
# Requirement already satisfied: split-folders in /home/algirosfs6/.local/lib/python3.10/site-packages (0.5.1)

# %%
import os # working with files/directories
import shutil # working with files/directories
import random

import cv2
import rasterio
from rasterio.plot import show

import numpy as np

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
font = {'family' : 'normal',
        'size'   : 14}
plt.rc('font', **font)

from patchify import patchify  #  cropping images
from patchify import unpatchify
import splitfolders #  splitting images to train/val folders

from tensorflow.keras.utils import to_categorical  # labels encoding
from tensorflow.keras.preprocessing.image import ImageDataGenerator # with datagenerator we don't keep the whole train data in RAM

from keras.models import Model  # UNET
from keras.models import load_model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
# Out:
# 2023-05-29 17:47:43.908687: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-05-29 17:47:43.910328: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-29 17:47:43.941182: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-29 17:47:43.942113: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-29 17:47:44.473049: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
if 'images' and 'masks' not in os.listdir():
    # !wget https://landcover.ai.linuxpolska.com/download/landcover.ai.v1.zip
    # !unzip landcover.ai.v1.zip
    # !rm landcover.ai.v1.zip
    print('Hola')
print('Files are ready to be used.')
    
os.listdir()
# Out:
# Files are ready to be used.
# ['.conda',
#  'train.txt',
#  'train_evaluation.py',
#  'pruebas_tfg.py',
#  'd_swin_utils.py',
#  'simclr_double_backbone.py',
#  'Miniconda3-latest-Linux-x86_64.sh',
#  'raster_clip',
#  'demo',
#  'splits',
#  'AED.ipynb',
#  'downstream_eval_scripts',
#  '.git',
#  'data',
#  'my_env.yml',
#  '.gitignore',
#  'train_resnet_backbone.py',
#  'masks',
#  'images',
#  'README.md',
#  'resnet_simclr.py',
#  'patches',
#  'utils.py',
#  'Transformer_SSL',
#  'validation_utils.py',
#  'readL2Sentinel.py',
#  'metrics.py',
#  'results.jpg',
#  'dfc_dataset.py',
#  'train_d_swin_backbone.py',
#  'split.py',
#  'simclr_utils.py',
#  'test.txt',
#  'dfc_sen12ms_dataset.py',
#  'requirements.txt',
#  'exceptions.py',
#  'paches',
#  'configs',
#  'Untitled-1.ipynb',
#  'dfc_model.py',
#  'pruebas_exploratorias.ipynb']

# %%
# !rm 'train.txt', 'split.py', 'test.txt', 'val.txt'
# Out:
# rm: cannot remove 'train.txt,': No such file or directory
# rm: cannot remove 'split.py,': No such file or directory
# rm: cannot remove 'test.txt,': No such file or directory
# rm: cannot remove 'val.txt': No such file or directory

# %%
image_names = os.listdir('images')
mask_names = os.listdir('masks')

# %%
print(f"Number of images: {len(image_names)}")
print(f"Number of masks: {len(mask_names)}")
# Out:
# Number of images: 41
# Number of masks: 41

# %%
name = image_names[0]
src = rasterio.open('images'+'/'+name)

print('File name: ' + src.name)
print(f'Number of channels: {src.count}')
print(f'Size: {src.width}x{src.height}')
print(f'Bounds: {src.bounds}')

src.close()
# Out:
# File name: images/N-34-140-A-b-3-2.tif
# Number of channels: 3
# Size: 8865x9579
# Bounds: BoundingBox(left=681094.7500005683, bottom=492746.24999624956, right=683311.0000005683, top=495140.99999624956)

# %%
labels = {0: 'None',
          1: 'building',
          2: 'woodland',
          3: 'water',
          4: 'road'} # from dataset website

index = random.randint(0,len(image_names)-1) # choose random image name
name = image_names[index]

fig, axs = plt.subplots(1, 2, figsize=(16,8))

with rasterio.open('images'+'/'+name) as src:
    image = src.read().transpose(1,2,0) 
    axs[0].imshow(image) # show image
    
with rasterio.open('masks'+'/'+name) as src:
    mask = src.read().transpose(1,2,0)
    im = axs[1].imshow(mask)  # show mask
    
    colors = [im.cmap(im.norm(value)) for value in labels.keys()] # colors from imshow
    patches = [mpatches.Patch(color=colors[i], label=labels[i]) for i in range(len(labels.keys()))] # creating legend info
    plt.legend(handles=patches) # add legend with labels

plt.show()
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
plt.figure(figsize=(8,8))
plt.hist(mask.flatten())
plt.show()

# %%
os.makedirs("256_patches/images")
os.makedirs("256_patches/masks")

# %%
def create_patches(input_folder, output_folder, patch_size = 256, datatype = 'image'):
    '''Crop images/masks from input_folder/ and save pathces (patch_size*patch_size) to output_folder/.
    Also works with images in subdirs.
    
    input_folder -- relative path to images source folder ('folder/../../')
    output_folder -- relative path to patches destination folder ('folder/../../')
    patch_size -- size of pathes (default 256). Recommended: 64/128/256/512
    datatype -- "image"" or "mask" (default 'image'), affects cv2_readmode
    '''
    
    if datatype == 'image':
        cv2_readmode = 1 # BGR readmode
    elif datatype == 'mask':
        cv2_readmode = 0 # Gray readmode
    else:
        print("Please, specify correct datatype: image or mask")
        print("Patches haven't been created.")
        return 0
    
    # Go through all subdirs and choose each read each image/mask
    for path, subdirs, files in os.walk(input_folder):
        names = os.listdir(path)
        for k, name in enumerate(names):
            if name.endswith(".tif"):
                # Read image/mask
                image = cv2.imread(path+"/"+name, cv2_readmode)
                print(f"Processing {k}nd {datatype} {name} with shape: {image.shape}.")
                
                # Crop image/mask
                SIZE_X = (image.shape[1]//patch_size)*patch_size
                SIZE_Y = (image.shape[0]//patch_size)*patch_size 
                image = image[:SIZE_Y, :SIZE_X] 
                
                # Create and save patches for image/mask (same algorithm but different shapes)
                if datatype == 'image':
                    patches = patchify(image, (patch_size, patch_size, 3), step=patch_size)
                    for i in range(patches.shape[0]): 
                        for j in range(patches.shape[1]):
                            single_patch = patches[i,j,0,:,:]
                            cv2.imwrite(output_folder+name.split('.', 1)[0]+"_patch_"+str(i)+str(j)+".tif",
                                        single_patch)
                elif datatype == 'mask':
                    patches = patchify(image, (patch_size, patch_size), step=patch_size)
                    for i in range(patches.shape[0]): 
                        for j in range(patches.shape[1]):
                            single_patch = patches[i,j]
                            cv2.imwrite(output_folder+name.split('.', 1)[0]+"_patch_"+str(i)+str(j)+".tif",
                                        single_patch)
                
                print(f"{k}nd {datatype} {name} is patched.")

# %%
create_patches('images/', '256_patches/images/', datatype='image')
# Out:
# Processing 0nd image N-34-140-A-b-3-2.tif with shape: (9579, 8865, 3).
# 0nd image N-34-140-A-b-3-2.tif is patched.
# Processing 1nd image N-33-60-D-d-1-2.tif with shape: (4697, 4127, 3).
# 1nd image N-33-60-D-d-1-2.tif is patched.
# Processing 2nd image N-33-130-A-d-3-3.tif with shape: (9543, 8782, 3).
# 2nd image N-33-130-A-d-3-3.tif is patched.
# Processing 3nd image N-34-94-A-b-2-4.tif with shape: (9697, 8746, 3).
# 3nd image N-34-94-A-b-2-4.tif is patched.
# Processing 4nd image M-34-32-B-b-1-3.tif with shape: (9607, 9075, 3).
# 4nd image M-34-32-B-b-1-3.tif is patched.
# Processing 5nd image M-33-7-A-d-3-2.tif with shape: (9715, 9088, 3).
# 5nd image M-33-7-A-d-3-2.tif is patched.
# Processing 6nd image N-33-104-A-c-1-1.tif with shape: (9671, 8788, 3).
# 6nd image N-33-104-A-c-1-1.tif is patched.
# Processing 7nd image N-34-97-D-c-2-4.tif with shape: (4672, 4230, 3).
# 7nd image N-34-97-D-c-2-4.tif is patched.
# Processing 8nd image M-34-65-D-a-4-4.tif with shape: (9425, 9107, 3).
# 8nd image M-34-65-D-a-4-4.tif is patched.
# Processing 9nd image M-33-7-A-d-2-3.tif with shape: (9711, 9081, 3).
# 9nd image M-33-7-A-d-2-3.tif is patched.
# Processing 10nd image N-34-61-B-a-1-1.tif with shape: (4678, 4113, 3).
# 10nd image N-34-61-B-a-1-1.tif is patched.
# Processing 11nd image N-34-140-A-d-4-2.tif with shape: (9587, 8889, 3).
# 11nd image N-34-140-A-d-4-2.tif is patched.
# Processing 12nd image M-34-5-D-d-4-2.tif with shape: (9441, 8825, 3).
# 12nd image M-34-5-D-d-4-2.tif is patched.
# Processing 13nd image M-34-51-C-b-2-1.tif with shape: (9289, 8891, 3).
# 13nd image M-34-51-C-b-2-1.tif is patched.
# Processing 14nd image M-33-20-D-d-3-3.tif with shape: (9631, 9095, 3).
# 14nd image M-33-20-D-d-3-3.tif is patched.
# Processing 15nd image M-34-56-A-b-1-4.tif with shape: (9582, 9170, 3).
# 15nd image M-34-56-A-b-1-4.tif is patched.
# Processing 16nd image N-34-106-A-c-1-3.tif with shape: (9674, 8797, 3).
# 16nd image N-34-106-A-c-1-3.tif is patched.
# Processing 17nd image N-33-139-D-c-1-3.tif with shape: (9704, 9042, 3).
# 17nd image N-33-139-D-c-1-3.tif is patched.
# Processing 18nd image N-34-106-A-b-3-4.tif with shape: (9692, 8808, 3).
# 18nd image N-34-106-A-b-3-4.tif is patched.
# Processing 19nd image N-33-139-C-d-2-2.tif with shape: (9706, 9042, 3).
# 19nd image N-33-139-C-d-2-2.tif is patched.
# Processing 20nd image N-33-130-A-d-4-4.tif with shape: (9533, 8771, 3).
# 20nd image N-33-130-A-d-4-4.tif is patched.
# Processing 21nd image M-33-32-B-b-4-4.tif with shape: (9621, 9098, 3).
# 21nd image M-33-32-B-b-4-4.tif is patched.
# Processing 22nd image M-34-68-B-a-1-3.tif with shape: (9594, 9243, 3).
# 22nd image M-34-68-B-a-1-3.tif is patched.
# Processing 23nd image M-33-20-D-c-4-2.tif with shape: (9636, 9095, 3).
# 23nd image M-33-20-D-c-4-2.tif is patched.
# Processing 24nd image M-33-48-A-c-4-4.tif with shape: (9429, 8973, 3).
# 24nd image M-33-48-A-c-4-4.tif is patched.
# Processing 25nd image M-34-65-D-d-4-1.tif with shape: (9436, 9130, 3).
# 25nd image M-34-65-D-d-4-1.tif is patched.
# Processing 26nd image M-34-55-B-b-4-1.tif with shape: (9556, 9147, 3).
# 26nd image M-34-55-B-b-4-1.tif is patched.
# Processing 27nd image N-33-119-C-c-3-3.tif with shape: (4750, 4352, 3).
# 27nd image N-33-119-C-c-3-3.tif is patched.
# Processing 28nd image N-33-96-D-d-1-1.tif with shape: (4699, 4227, 3).
# 28nd image N-33-96-D-d-1-1.tif is patched.
# Processing 29nd image M-34-32-B-a-4-3.tif with shape: (9599, 9075, 3).
# 29nd image M-34-32-B-a-4-3.tif is patched.
# Processing 30nd image M-34-6-A-d-2-2.tif with shape: (9470, 8818, 3).
# 30nd image M-34-6-A-d-2-2.tif is patched.
# Processing 31nd image N-34-77-A-b-1-4.tif with shape: (9404, 8351, 3).
# 31nd image N-34-77-A-b-1-4.tif is patched.
# Processing 32nd image N-33-60-D-c-4-2.tif with shape: (4701, 4136, 3).
# 32nd image N-33-60-D-c-4-2.tif is patched.
# Processing 33nd image M-34-51-C-d-4-1.tif with shape: (9289, 8914, 3).
# 33nd image M-34-51-C-d-4-1.tif is patched.
# Processing 34nd image N-34-66-C-c-4-3.tif with shape: (4727, 4199, 3).
# 34nd image N-34-66-C-c-4-3.tif is patched.
# Processing 35nd image N-34-140-A-b-4-2.tif with shape: (9586, 8873, 3).
# 35nd image N-34-140-A-b-4-2.tif is patched.
# Processing 36nd image M-34-65-D-c-4-2.tif with shape: (9426, 9119, 3).
# 36nd image M-34-65-D-c-4-2.tif is patched.
# Processing 37nd image N-34-97-C-b-1-2.tif with shape: (4683, 4232, 3).
# 37nd image N-34-97-C-b-1-2.tif is patched.
# Processing 38nd image N-33-139-C-d-2-4.tif with shape: (9707, 9046, 3).
# 38nd image N-33-139-C-d-2-4.tif is patched.
# Processing 39nd image M-34-77-B-c-2-3.tif with shape: (9423, 9142, 3).
# 39nd image M-34-77-B-c-2-3.tif is patched.
# Processing 40nd image N-34-140-A-d-3-4.tif with shape: (9579, 8885, 3).
# 40nd image N-34-140-A-d-3-4.tif is patched.

# %%
create_patches('masks/', '256_patches/masks/', datatype='mask')
# Out:
# Processing 0nd mask N-34-140-A-b-3-2.tif with shape: (9579, 8865).
# 0nd mask N-34-140-A-b-3-2.tif is patched.
# Processing 1nd mask N-33-60-D-d-1-2.tif with shape: (4697, 4127).
# 1nd mask N-33-60-D-d-1-2.tif is patched.
# Processing 2nd mask N-33-130-A-d-3-3.tif with shape: (9543, 8782).
# 2nd mask N-33-130-A-d-3-3.tif is patched.
# Processing 3nd mask N-34-94-A-b-2-4.tif with shape: (9697, 8746).
# 3nd mask N-34-94-A-b-2-4.tif is patched.
# Processing 4nd mask M-34-32-B-b-1-3.tif with shape: (9607, 9075).
# 4nd mask M-34-32-B-b-1-3.tif is patched.
# Processing 5nd mask M-33-7-A-d-3-2.tif with shape: (9715, 9088).
# 5nd mask M-33-7-A-d-3-2.tif is patched.
# Processing 6nd mask N-33-104-A-c-1-1.tif with shape: (9671, 8788).
# 6nd mask N-33-104-A-c-1-1.tif is patched.
# Processing 7nd mask N-34-97-D-c-2-4.tif with shape: (4672, 4230).
# 7nd mask N-34-97-D-c-2-4.tif is patched.
# Processing 8nd mask M-34-65-D-a-4-4.tif with shape: (9425, 9107).
# 8nd mask M-34-65-D-a-4-4.tif is patched.
# Processing 9nd mask M-33-7-A-d-2-3.tif with shape: (9711, 9081).
# 9nd mask M-33-7-A-d-2-3.tif is patched.
# Processing 10nd mask N-34-61-B-a-1-1.tif with shape: (4678, 4113).
# 10nd mask N-34-61-B-a-1-1.tif is patched.
# Processing 11nd mask N-34-140-A-d-4-2.tif with shape: (9587, 8889).
# 11nd mask N-34-140-A-d-4-2.tif is patched.
# Processing 12nd mask M-34-5-D-d-4-2.tif with shape: (9441, 8825).
# 12nd mask M-34-5-D-d-4-2.tif is patched.
# Processing 13nd mask M-34-51-C-b-2-1.tif with shape: (9289, 8891).
# 13nd mask M-34-51-C-b-2-1.tif is patched.
# Processing 14nd mask M-33-20-D-d-3-3.tif with shape: (9631, 9095).
# 14nd mask M-33-20-D-d-3-3.tif is patched.
# Processing 15nd mask M-34-56-A-b-1-4.tif with shape: (9582, 9170).
# 15nd mask M-34-56-A-b-1-4.tif is patched.
# Processing 16nd mask N-34-106-A-c-1-3.tif with shape: (9674, 8797).
# 16nd mask N-34-106-A-c-1-3.tif is patched.
# Processing 17nd mask N-33-139-D-c-1-3.tif with shape: (9704, 9042).
# 17nd mask N-33-139-D-c-1-3.tif is patched.
# Processing 18nd mask N-34-106-A-b-3-4.tif with shape: (9692, 8808).
# 18nd mask N-34-106-A-b-3-4.tif is patched.
# Processing 19nd mask N-33-139-C-d-2-2.tif with shape: (9706, 9042).
# 19nd mask N-33-139-C-d-2-2.tif is patched.
# Processing 20nd mask N-33-130-A-d-4-4.tif with shape: (9533, 8771).
# 20nd mask N-33-130-A-d-4-4.tif is patched.
# Processing 21nd mask M-33-32-B-b-4-4.tif with shape: (9621, 9098).
# 21nd mask M-33-32-B-b-4-4.tif is patched.
# Processing 22nd mask M-34-68-B-a-1-3.tif with shape: (9594, 9243).
# 22nd mask M-34-68-B-a-1-3.tif is patched.
# Processing 23nd mask M-33-20-D-c-4-2.tif with shape: (9636, 9095).
# 23nd mask M-33-20-D-c-4-2.tif is patched.
# Processing 24nd mask M-33-48-A-c-4-4.tif with shape: (9429, 8973).
# 24nd mask M-33-48-A-c-4-4.tif is patched.
# Processing 25nd mask M-34-65-D-d-4-1.tif with shape: (9436, 9130).
# 25nd mask M-34-65-D-d-4-1.tif is patched.
# Processing 26nd mask M-34-55-B-b-4-1.tif with shape: (9556, 9147).
# 26nd mask M-34-55-B-b-4-1.tif is patched.
# Processing 27nd mask N-33-119-C-c-3-3.tif with shape: (4750, 4352).
# 27nd mask N-33-119-C-c-3-3.tif is patched.
# Processing 28nd mask N-33-96-D-d-1-1.tif with shape: (4699, 4227).
# 28nd mask N-33-96-D-d-1-1.tif is patched.
# Processing 29nd mask M-34-32-B-a-4-3.tif with shape: (9599, 9075).
# 29nd mask M-34-32-B-a-4-3.tif is patched.
# Processing 30nd mask M-34-6-A-d-2-2.tif with shape: (9470, 8818).
# 30nd mask M-34-6-A-d-2-2.tif is patched.
# Processing 31nd mask N-34-77-A-b-1-4.tif with shape: (9404, 8351).
# 31nd mask N-34-77-A-b-1-4.tif is patched.
# Processing 32nd mask N-33-60-D-c-4-2.tif with shape: (4701, 4136).
# 32nd mask N-33-60-D-c-4-2.tif is patched.
# Processing 33nd mask M-34-51-C-d-4-1.tif with shape: (9289, 8914).
# 33nd mask M-34-51-C-d-4-1.tif is patched.
# Processing 34nd mask N-34-66-C-c-4-3.tif with shape: (4727, 4199).
# 34nd mask N-34-66-C-c-4-3.tif is patched.
# Processing 35nd mask N-34-140-A-b-4-2.tif with shape: (9586, 8873).
# 35nd mask N-34-140-A-b-4-2.tif is patched.
# Processing 36nd mask M-34-65-D-c-4-2.tif with shape: (9426, 9119).
# 36nd mask M-34-65-D-c-4-2.tif is patched.
# Processing 37nd mask N-34-97-C-b-1-2.tif with shape: (4683, 4232).
# 37nd mask N-34-97-C-b-1-2.tif is patched.
# Processing 38nd mask N-33-139-C-d-2-4.tif with shape: (9707, 9046).
# 38nd mask N-33-139-C-d-2-4.tif is patched.
# Processing 39nd mask M-34-77-B-c-2-3.tif with shape: (9423, 9142).
# 39nd mask M-34-77-B-c-2-3.tif is patched.
# Processing 40nd mask N-34-140-A-d-3-4.tif with shape: (9579, 8885).
# 40nd mask N-34-140-A-d-3-4.tif is patched.

# %%
num = len(os.listdir('256_patches/images'))
print("Number of images 256x256: " + str(num))

num = len(os.listdir('256_patches/masks'))
print("Number of masks 256x256: " + str(num))
# Out:
# Number of images 256x256: 41646
# Number of masks 256x256: 41646

# %%
train_img_dir = "256_patches/images/"
train_mask_dir = "256_patches/masks/"

img_list = os.listdir(train_img_dir)
msk_list = os.listdir(train_mask_dir)

num_images = len(os.listdir(train_img_dir))
img_num = random.randint(0, num_images-1)

img_for_plot = cv2.imread(train_img_dir+img_list[img_num], 1)
img_for_plot = cv2.cvtColor(img_for_plot, cv2.COLOR_BGR2RGB)

mask_for_plot = cv2.imread(train_mask_dir+msk_list[img_num], 0)

plt.figure(figsize=(12, 8))

plt.subplot(121)
plt.imshow(img_for_plot)
plt.title('Image')

plt.subplot(122)
plt.imshow(mask_for_plot, cmap='gray', vmin=0, vmax=4)
plt.title('Mask')
plt.show()
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
img_list.sort()
msk_list.sort()

# %%
os.makedirs("256_patches/images_with_useful_info/images")
os.makedirs("256_patches/images_with_useful_info/masks")

# %%
useless=0  # useless image counter

for index in range(len(img_list)):
    img_name = img_list[index]
    mask_name = msk_list[index]
    
    temp_image=cv2.imread(train_img_dir+img_list[index], 1)
    temp_mask=cv2.imread(train_mask_dir+msk_list[index], 0)
    
    val, counts = np.unique(temp_mask, return_counts=True)
    
    if (counts[0]/counts.sum()) > 0.95 and val[0] == 0: # if mask has less than 5% of usefull info we ignore it
        useless +=1
    else:
        cv2.imwrite('256_patches/images_with_useful_info/images/'+img_name, temp_image)
        cv2.imwrite('256_patches/images_with_useful_info/masks/'+mask_name, temp_mask)
  
    if index%1000 == 0:
        print(f'Current index {index}')

print("Total useful images are: ", len(img_list)-useless)
print("Total useless images are: ", useless)
# Out:
# Current index 0
# Current index 1000
# Current index 2000
# Current index 3000
# Current index 4000
# Current index 5000
# Current index 6000
# Current index 7000
# Current index 8000
# Current index 9000
# Current index 10000
# Current index 11000
# Current index 12000
# Current index 13000
# Current index 14000
# Current index 15000
# Current index 16000
# Current index 17000
# Current index 18000
# Current index 19000
# Current index 20000
# Current index 21000
# Current index 22000
# Current index 23000
# Current index 24000
# Current index 25000
# Current index 26000
# Current index 27000
# Current index 28000
# Current index 29000
# Current index 30000
# Current index 31000
# Current index 32000
# Current index 33000
# Current index 34000
# Current index 35000
# Current index 36000
# Current index 37000
# Current index 38000
# Current index 39000
# Current index 40000
# Current index 41000
# Total useful images are:  28210
# Total useless images are:  13436

# %%
with rasterio.open('256_patches/images/M-33-20-D-c-4-2_patch_00.tif') as src:
    patch = src.read().transpose(1,2,0)

with rasterio.open('images/M-33-20-D-c-4-2.tif') as src:
    image_part = src.read().transpose(1,2,0)[:256,:256,:]
# Out:
# /home/algirosfs6/.local/lib/python3.10/site-packages/rasterio/__init__.py:304: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)

# %%
plt.imshow(patch)
plt.show()
plt.imshow(image_part)
plt.show()

# %%
input_folder = '256_patches/images_with_useful_info/'
output_folder = 'data/'

splitfolders.ratio(input_folder, output=output_folder, seed=42, ratio=(.8, .2), group_prefix=None)
# Out:
# Copying files: 56420 files [00:04, 11749.14 files/s]

# %%
shutil.rmtree("256_patches")

# %%
for path, subdirs, files in os.walk("data/"):
    print(path)
# Out:
# data/
# data/train_masks
# data/train_masks/train
# data/val_images
# data/val_images/val
# data/train_images
# data/train_images/train
# data/val_masks
# data/val_masks/val
# data/train
# data/train/masks
# data/train/images
# data/val
# data/val/masks
# data/val/images

# %%
def copy_and_delete(src, dest, path="data/"):
    '''Copies all file from folder /src to /dest. After that delete /src'''
    
    src = path + src
    dest = path + dest
    
    try:
        os.makedirs(dest) # create new folder if doesn't exist
        print(f"Folder {dest} has been created.")
    except:
        print(f"Folder {dest} already exist.")
    
    for file_name in os.listdir(src):
        full_file_name = os.path.join(src, file_name)
        shutil.copy(full_file_name, dest)
    
    shutil.rmtree(src)
    print(f'All files sucesfully coppied and {src} has been removed.')

# %%
copy_and_delete("train/images", "train_images/train")
copy_and_delete("train/masks", "train_masks/train")
copy_and_delete("val/images", "val_images/val")
copy_and_delete("val/masks", "val_masks/val")
# Out:
# Folder data/train_images/train already exist.
# All files sucesfully coppied and data/train/images has been removed.
# Folder data/train_masks/train already exist.
# All files sucesfully coppied and data/train/masks has been removed.
# Folder data/val_images/val already exist.
# All files sucesfully coppied and data/val/images has been removed.
# Folder data/val_masks/val already exist.
# All files sucesfully coppied and data/val/masks has been removed.

# %%
shutil.rmtree("data/train")
shutil.rmtree("data/val")

# %%
for path, subdirs, files in os.walk("data/"):
    print(path)
# Out:
# data/
# data/train_masks
# data/train_masks/train
# data/val_images
# data/val_images/val
# data/train_images
# data/train_images/train
# data/val_masks
# data/val_masks/val

# %%
train_img_dir = "data/train_images/train/"
train_mask_dir = "data/train_masks/train/"

img_list = os.listdir(train_img_dir)
msk_list = os.listdir(train_mask_dir)

num_images = len(os.listdir(train_img_dir))
img_num = random.randint(0, num_images-1)

img_for_plot = cv2.imread(train_img_dir+img_list[img_num], 1)
img_for_plot = cv2.cvtColor(img_for_plot, cv2.COLOR_BGR2RGB)

mask_for_plot = cv2.imread(train_mask_dir+msk_list[img_num], 0)

plt.figure(figsize=(12, 8))

plt.subplot(121)
plt.imshow(img_for_plot)
plt.title('Image')

plt.subplot(122)
plt.imshow(mask_for_plot, vmin=0, vmax=4)
plt.title('Mask')
plt.show()

# %%
seed = 24
batch_size = 8
n_classes = 5

# %%
import numpy as np

def preprocess_data(img, mask, num_class):
    img = img / 255
    
    # Ajustar los valores de la máscara dentro del rango válido
    mask = np.clip(mask, 0, num_class-1)
    
    mask = to_categorical(mask, num_class)
    
    return (img, mask)

# %%
def trainGenerator(img_path, mask_path, num_class):
    
    img_data_gen_args = dict(horizontal_flip = True,
                            vertical_flip = True,
                            fill_mode = 'reflect')
    
    image_datagen = ImageDataGenerator(**img_data_gen_args)
    mask_datagen = ImageDataGenerator(**img_data_gen_args)
    
    image_generator = image_datagen.flow_from_directory(
        train_img_path,
        class_mode = None,
        batch_size = batch_size,
        seed = seed)
    
    mask_generator = mask_datagen.flow_from_directory(
        train_mask_path,
        class_mode = None,
        color_mode = 'grayscale',
        batch_size = batch_size,
        seed = seed)
    
    train_generator = zip(image_generator, mask_generator)
    
    for (img, mask) in train_generator:
        img, mask = preprocess_data(img, mask, num_class)
        yield (img, mask)

# %%
train_img_path = "data/train_images/"
train_mask_path = "data/train_masks/"
train_img_gen = trainGenerator(train_img_path, train_mask_path, num_class=n_classes)

# %%
val_img_path = "data/val_images/"
val_mask_path = "data/val_masks/"
val_img_gen = trainGenerator(val_img_path, val_mask_path, num_class=n_classes)

# %%
x, y = train_img_gen.__next__()

for i in range(batch_size//4):
    image = x[i]
    mask = np.argmax(y[i], axis=2)
    plt.subplot(1,2,1)
    plt.imshow(image)
    plt.subplot(1,2,2)
    plt.imshow(mask, vmin=0, vmax=4)
    plt.show()
# Out:
# Found 22696 images belonging to 1 classes.
# Found 22696 images belonging to 1 classes.
# Mask shape: (8, 256, 256, 1)
# Mask unique values: [0. 1. 2. 4.]

# %%
x_val, y_val = val_img_gen.__next__()

for i in range(batch_size//4):
    image = x_val[i]
    mask = np.argmax(y_val[i], axis=2)
    plt.subplot(1,2,1)
    plt.imshow(image)
    plt.subplot(1,2,2)
    plt.imshow(mask, vmin=0, vmax=4)
    plt.show()
# Out:
# Found 22696 images belonging to 1 classes.
# Found 22696 images belonging to 1 classes.
# Mask shape: (8, 256, 256, 1)
# Mask unique values: [0. 1. 2. 4.]

# %%
num_train_imgs = len(os.listdir('data/train_images/train/'))
num_val_imgs = len(os.listdir('data/val_images/val/'))
steps_per_epoch = num_train_imgs//batch_size
val_steps_per_epoch = num_val_imgs//batch_size

# %%
x.shape
# Out:
# (8, 256, 256, 3)

# %%
IMG_HEIGHT = x.shape[1]
IMG_WIDTH  = x.shape[2]
IMG_CHANNELS = x.shape[3]
n_classes=5

# %%
def multi_unet_model(n_classes=n_classes, IMG_HEIGHT=IMG_HEIGHT, IMG_WIDTH=IMG_WIDTH, IMG_CHANNELS=IMG_CHANNELS):

    inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
    s = inputs

    #Contraction path
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(s)
    c1 = Dropout(0.1)(c1)
    c1 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)
    
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
    c2 = Dropout(0.1)(c2)
    c2 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)
     
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
    c3 = Dropout(0.2)(c3)
    c3 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)
     
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
    c4 = Dropout(0.2)(c4)
    c4 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
    p4 = MaxPooling2D(pool_size=(2, 2))(c4)
     
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
    c5 = Dropout(0.3)(c5)
    c5 = Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)
    
    #Expansive path 
    u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = concatenate([u6, c4])
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u6)
    c6 = Dropout(0.2)(c6)
    c6 = Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c6)
     
    u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = concatenate([u7, c3])
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u7)
    c7 = Dropout(0.2)(c7)
    c7 = Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c7)
     
    u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = concatenate([u8, c2])
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u8)
    c8 = Dropout(0.1)(c8)
    c8 = Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c8)
     
    u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = concatenate([u9, c1], axis=3)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(u9)
    c9 = Dropout(0.1)(c9)
    c9 = Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c9)
     
    outputs = Conv2D(n_classes, (1, 1), activation='softmax')(c9)
    
    model = Model(inputs=[inputs], outputs=[outputs])
    
    return model

# %%
model_name = "landcover_10_epochs.hdf5"

if os.path.exists(model_name):
    model = load_model(model_name)
    print("Model is loaded.")
else:
    model = multi_unet_model()
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics='accuracy')
    print("Model is created.")
print(f"Number of params: {model.count_params()}")
# Out:
# 2023-05-29 17:54:24.828651: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1956] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
#
mask shape: (8, 256, 256, 1)
# Mask unique values: [0. 2. 3. 4.]
#  731/2837 [======>.......................] - ETA: 8:27 - loss: 0.9811 - accuracy: 0.5934Mask shape: (8, 256, 256, 1)
# Mask unique values: [0. 1. 2. 3. 4.]
#  732/2837 [======>.......................] - ETA: 8:27 - loss: 0.9809 - accuracy: 0.5934Mask shape: (8, 256, 256, 1)
# Mask unique values: [0. 2. 3. 4.]
#  733/2837 [======>.......................] - ETA: 8:27 - loss: 0.9806 - accuracy: 0.5935Mask shape: (8, 256, 256, 1)
# Mask unique values: [0. 1. 2. 4.]
#  734/2837 [======>.......................] - ETA: 8:27 - loss: 0.9804 - accuracy: 0.5936Mask shape: (8, 256, 256, 1)
# Mask unique values: [0. 1. 2. 3. 4.]
#  735/2837 [======>.......................] - ETA: 8:26 - loss: 0.9801 - accuracy: 0.5937Mask shape: (8, 256, 256, 1)
# Mask unique values: [0. 1. 2. 3. 4.]
#  736/2837 [======>.......................] - ETA: 8:26 - loss: 0.9806 - accuracy: 0.5935Mask shape: (8, 256, 256, 1)
# Mask unique values: [0. 1. 2. 3. 4.]
#  737/2837 [======>.......................] - ETA: 8:26 - loss: 0.9807 - accuracy: 0.5933Mask shape: (8, 256, 256, 1)
# Mask unique values: [0. 1. 2. 3. 4.]
#  738/2837 [======>.......................] - ETA: 8:26 - loss: 0.9804 - accuracy: 0.5933

# %%
model.save("landcover_30_epochs.hdf5")

# %%
plt.figure(figsize=(6,6))
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='vall_loss')
plt.legend()
plt.show()

plt.figure(figsize=(6,6))
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label='val_accuracy')
plt.legend()
plt.show()

# %%
x, y = train_img_gen.__next__()
predict = model.predict(x)

for i in range(batch_size//2):
    
    plt.figure(figsize=(12,4))
    image = x[i]
    mask = np.argmax(y[i], axis=2)
    predict_mask = np.argmax(predict[i], axis=2)

    plt.subplot(1,3,1)
    plt.imshow(image)
    
    plt.subplot(1,3,2)
    plt.imshow(mask, vmin=0, vmax=4)
    
    plt.subplot(1,3,3)
    plt.imshow(predict_mask, vmin=0, vmax=4)
    
    plt.show()

# %%
x, y = val_img_gen.__next__()
predict = model.predict(x)

for i in range(batch_size//2):
    
    plt.figure(figsize=(12,4))
    image = x[i]
    print(y[i].shape)
    mask = np.argmax(y[i], axis=-1)
    predict_mask = np.argmax(predict[i], axis=-1)

    plt.subplot(1,3,1)
    plt.imshow(image)
    
    plt.subplot(1,3,2)
    plt.imshow(mask, vmin=0, vmax=4)
    
    plt.subplot(1,3,3)
    plt.imshow(predict_mask, vmin=0, vmax=4)
    
    plt.show()

# %%
patch_size = 256
name = 'N-34-97-D-c-2-4.tif'

image = cv2.imread('images/' + name, 1)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)/255

mask = cv2.imread('masks/' + name, 0)

SIZE_X = (image.shape[1]//patch_size)*patch_size
SIZE_Y = (image.shape[0]//patch_size)*patch_size

image = image[:SIZE_Y, :SIZE_X]
mask = mask[:SIZE_Y, :SIZE_X]

patches_img = patchify(image, (patch_size, patch_size, 3), step=patch_size)
patches_mask = np.ones(patchify(mask, (patch_size, patch_size), step=patch_size).shape)*255

for i in range(patches_img.shape[0]):
    for j in range(patches_img.shape[1]):
            temp_img = patches_img[i,j,:,:,:,:]
            temp_mask = model.predict(temp_img)
            temp_mask = np.argmax(temp_mask, axis = -1)
            patches_mask[i,j] = temp_mask[0,:,:]

mask_predicted = unpatchify(patches_mask, mask.shape).astype(int)

del patches_mask
del patches_img

# %%
plt.figure(figsize=(18,6))

plt.subplot(1,3,1)
plt.title('Image')
plt.imshow(image)

plt.subplot(1,3,2)
plt.title('Real mask')
plt.imshow(mask, vmin=0, vmax=4)

plt.subplot(1,3,3)
plt.title('Predicted mask')
plt.imshow(mask_predicted, vmin=0, vmax=4)

plt.show()
